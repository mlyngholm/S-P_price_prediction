# %% [markdown]
# ## Import dataset

# %%
import pandas as pd

# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /Users/marielyngholm/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages (0.1.74)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/marielyngholm/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: pandas>=0.24.0 in /Users/marielyngholm/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages (from yfinance) (1.3.5)
# Requirement already satisfied: lxml>=4.5.1 in /Users/marielyngholm/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages (from yfinance) (4.7.1)
# Requirement already satisfied: numpy>=1.15 in /Users/marielyngholm/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages (from yfinance) (1.22.3)
# Requirement already satisfied: requests>=2.26 in /Users/marielyngholm/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages (from yfinance) (2.27.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/marielyngholm/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages (from pandas>=0.24.0->yfinance) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/marielyngholm/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/marielyngholm/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/marielyngholm/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages (from requests>=2.26->yfinance) (2.0.10)
# Requirement already satisfied: idna<4,>=2.5 in /Users/marielyngholm/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/marielyngholm/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages (from requests>=2.26->yfinance) (1.26.7)
# Requirement already satisfied: six>=1.5 in /Users/marielyngholm/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.14.0)
# WARNING: You are using pip version 22.0.3; however, version 22.2 is available.
# You should consider upgrading via the '/Users/marielyngholm/.pyenv/versions/3.8.12/envs/lewagon/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

sp500 = yf.Ticker("^GSPC")

# %%
sp500 = sp500.history(period="max")

# %%
sp500
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 1950-01-03    16.660000    16.660000    16.660000    16.660000     1260000
# 1950-01-04    16.850000    16.850000    16.850000    16.850000     1890000
# 1950-01-05    16.930000    16.930000    16.930000    16.930000     2550000
# 1950-01-06    16.980000    16.980000    16.980000    16.980000     2010000
# 1950-01-09    17.080000    17.080000    17.080000    17.080000     2520000
# ...                 ...          ...          ...          ...         ...
# 2022-07-20  3935.320068  3974.129883  3922.030029  3959.899902  3452150000
# 2022-07-21  3955.469971  3999.290039  3927.639893  3998.949951  3586030000
# 2022-07-22  3998.429932  4012.439941  3938.860107  3961.629883  3246220000
# 2022-07-25  3965.719971  3975.300049  3943.459961  3966.840088  2988650000
# 2022-07-26  3953.219971  3953.219971  3915.459961  3926.520020   948534216
#
#             Dividends  Stock Splits
# Date
# 1950-01-03          0             0
# 1950-01-04          0             0
# 1950-01-05          0             0
# 1950-01-06          0             0
# 1950-01-09          0             0
# ...               ...           ...
# 2022-07-20          0             0
# 2022-07-21          0             0
# 2022-07-22          0             0
# 2022-07-25          0             0
# 2022-07-26          0             0
#
# [18259 rows x 7 columns]

# %%
sp500.index
# Out:
# DatetimeIndex(['1950-01-03', '1950-01-04', '1950-01-05', '1950-01-06',
#                '1950-01-09', '1950-01-10', '1950-01-11', '1950-01-12',
#                '1950-01-13', '1950-01-16',
#                ...
#                '2022-07-13', '2022-07-14', '2022-07-15', '2022-07-18',
#                '2022-07-19', '2022-07-20', '2022-07-21', '2022-07-22',
#                '2022-07-25', '2022-07-26'],
#               dtype='datetime64[ns]', name='Date', length=18259, freq=None)

# %% [markdown]
# ## Cleaning data

# %%
sp500.plot.line(y="Close", use_index=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
del sp500["Dividends"]
del sp500["Stock Splits"]

# %% [markdown]
# #### Will the price go up or down tomorrow?

# %%
 sp500["Tomorrow"] = sp500["Close"].shift(-1)

# %%
 sp500["Target"] = (sp500["Tomorrow"] > sp500["Close"]).astype(int)

# %%
 sp500
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 1950-01-03    16.660000    16.660000    16.660000    16.660000     1260000
# 1950-01-04    16.850000    16.850000    16.850000    16.850000     1890000
# 1950-01-05    16.930000    16.930000    16.930000    16.930000     2550000
# 1950-01-06    16.980000    16.980000    16.980000    16.980000     2010000
# 1950-01-09    17.080000    17.080000    17.080000    17.080000     2520000
# ...                 ...          ...          ...          ...         ...
# 2022-07-20  3935.320068  3974.129883  3922.030029  3959.899902  3452150000
# 2022-07-21  3955.469971  3999.290039  3927.639893  3998.949951  3586030000
# 2022-07-22  3998.429932  4012.439941  3938.860107  3961.629883  3246220000
# 2022-07-25  3965.719971  3975.300049  3943.459961  3966.840088  2988650000
# 2022-07-26  3953.219971  3953.219971  3915.459961  3926.520020   948534216
#
#                Tomorrow  Target
# Date
# 1950-01-03    16.850000       1
# 1950-01-04    16.930000       1
# 1950-01-05    16.980000       1
# 1950-01-06    17.080000       1
# 1950-01-09    17.030001       0
# ...                 ...     ...
# 2022-07-20  3998.949951       1
# 2022-07-21  3961.629883       0
# 2022-07-22  3966.840088       1
# 2022-07-25  3926.520020       0
# 2022-07-26          NaN       0
#
# [18259 rows x 7 columns]

# %%
sp500 = sp500.loc["1990-01-01":].copy()

# %%
sp500
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 1990-01-02   353.399994   359.690002   351.980011   359.690002   162070000
# 1990-01-03   359.690002   360.589996   357.890015   358.760010   192330000
# 1990-01-04   358.760010   358.760010   352.890015   355.670013   177000000
# 1990-01-05   355.670013   355.670013   351.350006   352.200012   158530000
# 1990-01-08   352.200012   354.239990   350.540009   353.790009   140110000
# ...                 ...          ...          ...          ...         ...
# 2022-07-20  3935.320068  3974.129883  3922.030029  3959.899902  3452150000
# 2022-07-21  3955.469971  3999.290039  3927.639893  3998.949951  3586030000
# 2022-07-22  3998.429932  4012.439941  3938.860107  3961.629883  3246220000
# 2022-07-25  3965.719971  3975.300049  3943.459961  3966.840088  2988650000
# 2022-07-26  3953.219971  3953.219971  3915.459961  3926.520020   948534216
#
#                Tomorrow  Target
# Date
# 1990-01-02   358.760010       0
# 1990-01-03   355.670013       0
# 1990-01-04   352.200012       0
# 1990-01-05   353.790009       1
# 1990-01-08   349.619995       0
# ...                 ...     ...
# 2022-07-20  3998.949951       1
# 2022-07-21  3961.629883       0
# 2022-07-22  3966.840088       1
# 2022-07-25  3926.520020       0
# 2022-07-26          NaN       0
#
# [8205 rows x 7 columns]

# %% [markdown]
# ## Training an initial ML model

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)


# All rows except the last 100 into the training set
train = sp500.iloc[:-100]
test = sp500.iloc[-100:]

predictors = ["Close", "Volume", "Open", "High", "Low"]
model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %% [markdown]
# What percentage of the time did the market actually go up when we said it would go up?

# %%
from sklearn.metrics import precision_score

preds = model.predict(test[predictors])

# %%
preds = pd.Series(preds, index=test.index)
preds
# Out:
# Date
# 2022-03-03    0
# 2022-03-04    1
# 2022-03-07    1
# 2022-03-08    1
# 2022-03-09    1
#              ..
# 2022-07-20    0
# 2022-07-21    0
# 2022-07-22    1
# 2022-07-25    1
# 2022-07-26    1
# Length: 100, dtype: int64

# %%
precision_score(test["Target"], preds)
# Out:
# 0.4935064935064935

# %%
combined = pd.concat([test["Target"], preds], axis=1)

# %%
combined.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
def backtest(data, model, predictors, start=2500, step=250):
    
    all_predictions = []
    
    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    return pd.concat(all_predictions)

# %%
predictions = backtest(sp500, model, predictors, start=2500, step=250)
predictions
# Out:
#             Target  Predictions
# Date
# 1999-11-22       0            0
# 1999-11-23       1            0
# 1999-11-24       0            0
# 1999-11-26       0            0
# 1999-11-29       0            0
# ...            ...          ...
# 2022-07-20       1            0
# 2022-07-21       0            0
# 2022-07-22       1            1
# 2022-07-25       0            1
# 2022-07-26       0            0
#
# [5705 rows x 2 columns]

# %%
predictions["Predictions"].value_counts()
# Out:
# 0    3332
# 1    2373
# Name: Predictions, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5351875263379688

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5351875263379688

# %%
# Is that good enough? Lets look at the value counts of the target

predictions["Target"].value_counts() / predictions.shape[0] * 100
# Out:
# 1    53.63716
# 0    46.36284
# Name: Target, dtype: float64

# %% [markdown]
# ### Adding additional predictors

# %%
horizons = [2,5,60, 250,1000]

new_predictors = []

for horizon in horizons:
    rolling_averages = sp500.rolling(horizon).mean()
    
    ratio_column = f"Close_Ratio_{horizon}"
    sp500[ratio_column] = sp500["Close"] / rolling_averages["Close"]
    
    trend_column = f"Trend_{horizon}"
    sp500[trend_column] = sp500.shift(1).rolling(horizon).sum()["Target"]
    
    new_predictors += [ratio_column, trend_column]

# %%
sp500
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 1990-01-02   353.399994   359.690002   351.980011   359.690002   162070000
# 1990-01-03   359.690002   360.589996   357.890015   358.760010   192330000
# 1990-01-04   358.760010   358.760010   352.890015   355.670013   177000000
# 1990-01-05   355.670013   355.670013   351.350006   352.200012   158530000
# 1990-01-08   352.200012   354.239990   350.540009   353.790009   140110000
# ...                 ...          ...          ...          ...         ...
# 2022-07-20  3935.320068  3974.129883  3922.030029  3959.899902  3452150000
# 2022-07-21  3955.469971  3999.290039  3927.639893  3998.949951  3586030000
# 2022-07-22  3998.429932  4012.439941  3938.860107  3961.629883  3246220000
# 2022-07-25  3965.719971  3975.300049  3943.459961  3966.840088  2988650000
# 2022-07-26  3953.219971  3953.219971  3915.459961  3926.520020   948534216
#
#                Tomorrow  Target  Close_Ratio_2  Trend_2  Close_Ratio_5  \
# Date
# 1990-01-02   358.760010       0            NaN      NaN            NaN
# 1990-01-03   355.670013       0       0.998706      NaN            NaN
# 1990-01-04   352.200012       0       0.995675      0.0            NaN
# 1990-01-05   353.790009       1       0.995098      0.0            NaN
# 1990-01-08   349.619995       0       1.002252      1.0       0.993731
# ...                 ...     ...            ...      ...            ...
# 2022-07-20  3998.949951       1       1.002939      2.0       1.021594
# 2022-07-21  3961.629883       0       1.004906      2.0       1.020684
# 2022-07-22  3966.840088       1       0.995312      1.0       1.006102
# 2022-07-25  3926.520020       0       1.000657      1.0       1.000514
# 2022-07-26          NaN       0       0.994892      1.0       0.990853
#
#             Trend_5  Close_Ratio_60  Trend_60  Close_Ratio_250  Trend_250  \
# Date
# 1990-01-02      NaN             NaN       NaN              NaN        NaN
# 1990-01-03      NaN             NaN       NaN              NaN        NaN
# 1990-01-04      NaN             NaN       NaN              NaN        NaN
# 1990-01-05      NaN             NaN       NaN              NaN        NaN
# 1990-01-08      NaN             NaN       NaN              NaN        NaN
# ...             ...             ...       ...              ...        ...
# 2022-07-20      3.0        0.998462      29.0         0.905079      126.0
# 2022-07-21      4.0        1.009569      29.0         0.914350      126.0
# 2022-07-22      3.0        1.001047      29.0         0.906198      125.0
# 2022-07-25      4.0        1.003281      29.0         0.907751      126.0
# 2022-07-26      3.0        0.994597      28.0         0.898914      126.0
#
#             Close_Ratio_1000  Trend_1000
# Date
# 1990-01-02               NaN         NaN
# 1990-01-03               NaN         NaN
# 1990-01-04               NaN         NaN
# 1990-01-05               NaN         NaN
# 1990-01-08               NaN         NaN
# ...                      ...         ...
# 2022-07-20          1.131286       548.0
# 2022-07-21          1.142056       548.0
# 2022-07-22          1.131027       548.0
# 2022-07-25          1.132146       548.0
# 2022-07-26          1.120291       547.0
#
# [8205 rows x 17 columns]

# %%
sp500 = sp500.dropna()
sp500
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 1993-12-14   465.730011   466.119995   462.459991   463.059998   275050000
# 1993-12-15   463.059998   463.690002   461.839996   461.839996   331770000
# 1993-12-16   461.859985   463.980011   461.859985   463.339996   284620000
# 1993-12-17   463.339996   466.380005   463.339996   466.380005   363750000
# 1993-12-20   466.380005   466.899994   465.529999   465.850006   255900000
# ...                 ...          ...          ...          ...         ...
# 2022-07-19  3860.729980  3939.810059  3860.729980  3936.689941  3160350000
# 2022-07-20  3935.320068  3974.129883  3922.030029  3959.899902  3452150000
# 2022-07-21  3955.469971  3999.290039  3927.639893  3998.949951  3586030000
# 2022-07-22  3998.429932  4012.439941  3938.860107  3961.629883  3246220000
# 2022-07-25  3965.719971  3975.300049  3943.459961  3966.840088  2988650000
#
#                Tomorrow  Target  Close_Ratio_2  Trend_2  Close_Ratio_5  \
# Date
# 1993-12-14   461.839996       0       0.997157      1.0       0.996617
# 1993-12-15   463.339996       1       0.998681      0.0       0.995899
# 1993-12-16   466.380005       1       1.001621      1.0       0.999495
# 1993-12-17   465.850006       0       1.003270      2.0       1.004991
# 1993-12-20   465.299988       0       0.999431      1.0       1.003784
# ...                 ...     ...            ...      ...            ...
# 2022-07-19  3959.899902       1       1.013626      1.0       1.023961
# 2022-07-20  3998.949951       1       1.002939      2.0       1.021594
# 2022-07-21  3961.629883       0       1.004906      2.0       1.020684
# 2022-07-22  3966.840088       1       0.995312      1.0       1.006102
# 2022-07-25  3926.520020       0       1.000657      1.0       1.000514
#
#             Trend_5  Close_Ratio_60  Trend_60  Close_Ratio_250  Trend_250  \
# Date
# 1993-12-14      1.0        1.000283      32.0         1.028047      127.0
# 1993-12-15      1.0        0.997329      32.0         1.025151      126.0
# 1993-12-16      2.0        1.000311      32.0         1.028274      127.0
# 1993-12-17      3.0        1.006561      32.0         1.034781      128.0
# 1993-12-20      2.0        1.005120      32.0         1.033359      128.0
# ...             ...             ...       ...              ...        ...
# 2022-07-19      2.0        0.991311      28.0         0.899439      126.0
# 2022-07-20      3.0        0.998462      29.0         0.905079      126.0
# 2022-07-21      4.0        1.009569      29.0         0.914350      126.0
# 2022-07-22      3.0        1.001047      29.0         0.906198      125.0
# 2022-07-25      4.0        1.003281      29.0         0.907751      126.0
#
#             Close_Ratio_1000  Trend_1000
# Date
# 1993-12-14          1.176082       512.0
# 1993-12-15          1.172676       512.0
# 1993-12-16          1.176163       513.0
# 1993-12-17          1.183537       514.0
# 1993-12-20          1.181856       513.0
# ...                      ...         ...
# 2022-07-19          1.125027       547.0
# 2022-07-20          1.131286       548.0
# 2022-07-21          1.142056       548.0
# 2022-07-22          1.131027       548.0
# 2022-07-25          1.132146       548.0
#
# [7204 rows x 17 columns]

# %% [markdown]
# ## Improving the model

# %%
model = RandomForestClassifier(n_estimators=50, min_samples_split=100, random_state=1)

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict_proba(test[predictors])[:,1]
    preds[preds >= 0.6] = 1 
    preds[preds < 0.6] = 0
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
predictions = backtest(sp500, model, new_predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# 0.0    3869
# 1.0     835
# Name: Predictions, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.577245508982036

# %% [markdown]
# ## Improve - next steps

# %% [markdown]
# - gridsearch on randomforest
# - timeseries ARIMA
# - fb prophet

# %%
sp500
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 1993-12-14   465.730011   466.119995   462.459991   463.059998   275050000
# 1993-12-15   463.059998   463.690002   461.839996   461.839996   331770000
# 1993-12-16   461.859985   463.980011   461.859985   463.339996   284620000
# 1993-12-17   463.339996   466.380005   463.339996   466.380005   363750000
# 1993-12-20   466.380005   466.899994   465.529999   465.850006   255900000
# ...                 ...          ...          ...          ...         ...
# 2022-07-19  3860.729980  3939.810059  3860.729980  3936.689941  3160350000
# 2022-07-20  3935.320068  3974.129883  3922.030029  3959.899902  3452150000
# 2022-07-21  3955.469971  3999.290039  3927.639893  3998.949951  3586030000
# 2022-07-22  3998.429932  4012.439941  3938.860107  3961.629883  3246220000
# 2022-07-25  3965.719971  3975.300049  3943.459961  3966.840088  2988650000
#
#                Tomorrow  Target  Close_Ratio_2  Trend_2  Close_Ratio_5  \
# Date
# 1993-12-14   461.839996       0       0.997157      1.0       0.996617
# 1993-12-15   463.339996       1       0.998681      0.0       0.995899
# 1993-12-16   466.380005       1       1.001621      1.0       0.999495
# 1993-12-17   465.850006       0       1.003270      2.0       1.004991
# 1993-12-20   465.299988       0       0.999431      1.0       1.003784
# ...                 ...     ...            ...      ...            ...
# 2022-07-19  3959.899902       1       1.013626      1.0       1.023961
# 2022-07-20  3998.949951       1       1.002939      2.0       1.021594
# 2022-07-21  3961.629883       0       1.004906      2.0       1.020684
# 2022-07-22  3966.840088       1       0.995312      1.0       1.006102
# 2022-07-25  3926.520020       0       1.000657      1.0       1.000514
#
#             Trend_5  Close_Ratio_60  Trend_60  Close_Ratio_250  Trend_250  \
# Date
# 1993-12-14      1.0        1.000283      32.0         1.028047      127.0
# 1993-12-15      1.0        0.997329      32.0         1.025151      126.0
# 1993-12-16      2.0        1.000311      32.0         1.028274      127.0
# 1993-12-17      3.0        1.006561      32.0         1.034781      128.0
# 1993-12-20      2.0        1.005120      32.0         1.033359      128.0
# ...             ...             ...       ...              ...        ...
# 2022-07-19      2.0        0.991311      28.0         0.899439      126.0
# 2022-07-20      3.0        0.998462      29.0         0.905079      126.0
# 2022-07-21      4.0        1.009569      29.0         0.914350      126.0
# 2022-07-22      3.0        1.001047      29.0         0.906198      125.0
# 2022-07-25      4.0        1.003281      29.0         0.907751      126.0
#
#             Close_Ratio_1000  Trend_1000
# Date
# 1993-12-14          1.176082       512.0
# 1993-12-15          1.172676       512.0
# 1993-12-16          1.176163       513.0
# 1993-12-17          1.183537       514.0
# 1993-12-20          1.181856       513.0
# ...                      ...         ...
# 2022-07-19          1.125027       547.0
# 2022-07-20          1.131286       548.0
# 2022-07-21          1.142056       548.0
# 2022-07-22          1.131027       548.0
# 2022-07-25          1.132146       548.0
#
# [7204 rows x 17 columns]

# %%
sp500.shape
# Out:
# (7204, 17)

# %% [markdown]
# ## ARIMA

# %% [markdown]
# ### Visualize

# %%
df = sp500.copy()
df = df[["Close"]]
df
# Out:
#                   Close
# Date
# 1993-12-14   463.059998
# 1993-12-15   461.839996
# 1993-12-16   463.339996
# 1993-12-17   466.380005
# 1993-12-20   465.850006
# ...                 ...
# 2022-07-19  3936.689941
# 2022-07-20  3959.899902
# 2022-07-21  3998.949951
# 2022-07-22  3961.629883
# 2022-07-25  3966.840088
#
# [7204 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(df["Close"])
plt.xlabel("Year")
plt.ylabel("Closing price")
plt.title("SP500 Closing price")
# Out:
# Text(0.5, 1.0, 'SP500 Closing price')

# %% [markdown]
# ### Is is stationary?

# %% [markdown]
# #### ADF test

# %%
from statsmodels.tsa.stattools import adfuller

adfuller(df.Close)[1]  # p-value
# Out:
# 0.9902000367798324

# %% [markdown]
# The data is not stationary as we do not have a p-value of less than 0.05

# %% [markdown]
# #### Decompose

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

result = seasonal_decompose(df["Close"], model="multiplicative", period=30)

fig = plt.figure()
fig = result.plot()
fig.set_size_inches(16,9)

# %% [markdown]
# ### Convert non-stationary to stationary

# %% [markdown]
# #### Differencing

# %%
zero_diff = df.Close
first_order_diff = df.Close.diff(1)
second_order_diff = df.Close.diff(1).diff(1)


fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20,4))
ax1.plot(zero_diff); ax1.set_title('Original Series')
ax2.plot(first_order_diff); ax2.set_title('1st Order Differencing')
ax3.plot(second_order_diff); ax3.set_title('2nd Order Differencing');

# %% [markdown]
# ### Train-Test split

# %%
df.shape
# Out:
# (7204, 1)

# %%
y = df.Close

train_size = 0.8
index = round(train_size*df.shape[0])

df_train = df.iloc[:index]
df_test = df.iloc[index:]

# %%
df_train, df_test
# Out:
# (                  Close
#  Date
#  1993-12-14   463.059998
#  1993-12-15   461.839996
#  1993-12-16   463.339996
#  1993-12-17   466.380005
#  1993-12-20   465.850006
#  ...                 ...
#  2016-10-25  2143.159912
#  2016-10-26  2139.429932
#  2016-10-27  2133.040039
#  2016-10-28  2126.409912
#  2016-10-31  2126.149902
#
#  [5763 rows x 1 columns],
#                    Close
#  Date
#  2016-11-01  2111.719971
#  2016-11-02  2097.939941
#  2016-11-03  2088.659912
#  2016-11-04  2085.179932
#  2016-11-07  2131.520020
#  ...                 ...
#  2022-07-19  3936.689941
#  2022-07-20  3959.899902
#  2022-07-21  3998.949951
#  2022-07-22  3961.629883
#  2022-07-25  3966.840088
#
#  [1441 rows x 1 columns])

# %% [markdown]
# ### Auto ARIMA

# %%
import pmdarima as pm

smodel = pm.auto_arima(df["Close"],
                      start_p=1, max_p=2,
                       start_q=1, max_q=2,
                       trend='t',
                       seasonal=False,
                       trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=64514.218, Time=0.39 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=64604.973, Time=0.52 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=64519.672, Time=0.40 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=64526.623, Time=1.14 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=64604.973, Time=0.46 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=64513.124, Time=1.21 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=64511.121, Time=0.64 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=64511.121, Time=0.64 sec
#
# Best model:  ARIMA(2,1,0)(0,0,0)[0] intercept
# Total fit time: 5.422 seconds

# %% [markdown]
# ### ARIMA model

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(df_train, order=(2,1,0))
fitted = model.fit()
# Out:
# /Users/marielyngholm/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/marielyngholm/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/marielyngholm/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %% [markdown]
# ### Model Prediction

# %%
df_test.shape
# Out:
# (1441, 1)

# %%
fc, se, conf = fitted.forecast(1441, alpha=0.05)
fc_series = pd.Series(fc, index=df_test.index)

# %% [markdown]
# ### Baseline model

# %%
y_pred = df_test.shift(1)
y_pred
# Out:
#                   Close
# Date
# 2016-11-01          NaN
# 2016-11-02  2111.719971
# 2016-11-03  2097.939941
# 2016-11-04  2088.659912
# 2016-11-07  2085.179932
# ...                 ...
# 2022-07-19  3830.850098
# 2022-07-20  3936.689941
# 2022-07-21  3959.899902
# 2022-07-22  3998.949951
# 2022-07-25  3961.629883
#
# [1441 rows x 1 columns]

# %%
y_pred = df_test.shift(1).dropna()
y_true = df_test[1:]

from sklearn.metrics import r2_score

r2_score(y_pred, y_true)
# Out:
# 0.9971274676411521

# %% [markdown]
# ### Decomposition

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
result_add = seasonal_decompose(sp500["Close"], model='additive')
result_add.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/09/89vgqkmd3mq14q_6bkk_t7vm0000gn/T/ipykernel_11090/2145440600.py in <module>
# ----> 1 result_add = seasonal_decompose(sp500["Close"], model='additive')
#       2 result_add.plot()
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/statsmodels/tsa/seasonal.py in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     157             period = pfreq
#     158         else:
# --> 159             raise ValueError(
#     160                 "You must specify a period or x must be a pandas object with "
#     161                 "a PeriodIndex or a DatetimeIndex with a freq not set to None"
#
# ValueError: You must specify a period or x must be a pandas object with a PeriodIndex or a DatetimeIndex with a freq not set to None

# %% [markdown]
# The trend is not stationary. We need to apply differencing to make it stationary

# %% [markdown]
# ### Stationarity

# %%
from statsmodels.tsa.stattools import adfuller

adfuller(df.Close)[1]  # p-value

# %%
fig, axes = plt.subplots(1,2, figsize=(16,3))

plot_acf(df.Close, lags=50, ax=axes[0]);
plot_pacf(df.Close, lags=50, ax=axes[1], color='r');

# %% [markdown]
# ### Differencing

# %%
print('p-value: ', adfuller(y.diff(1).fillna(0))[1])

# %%
y_diff = y.diff().dropna()

# %%
# Let's remove seasons
df['deseasonalized'] = df.Close.values/result_mul.seasonal

plt.figure(figsize=(15,4)); plt.subplot(1,2,1); plt.plot(df.deseasonalized);
plt.title('Drug Sales Deseasonalized', fontsize=16);

# Also remove exponential trend 
df['linearized'] = np.log(df['deseasonalized'])

plt.subplot(1,2,2); plt.plot(df['linearized'])
plt.title('Drug Sales Linearized', fontsize=16);

# %% [markdown]
# ### Plot ACF and PACF

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plot_acf(y_diff);

# %%
plot_pacf(y_diff, method="ywm", c="r");
